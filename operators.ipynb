# %%
x=20; y=3
sum=x+y
sub=x-y
mult=x*y
div=round(x/y , 2)
mod=x%y
print(sum, sub, mult, div, mod)
# Out:
# 23 17 60 6.67 2

# %%
x= 10; y= 3

greater_than= x > y 
print(greater_than)
# Out:
# True

# %%
#precedence and associativity 
#(/, *)=> Higher precedence (Count: Left -> Right)
#(+, -)=> Lower precedence  (Count: left -> Right)

pa=10+10/2-5*2
print(pa) #10+5-10
          #15-10
          # 5
# Out:
# 5.0

# %%
#Problem Solving :Digital Summation
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
mod1=num1%10
mod2=num2%10

sum=mod1+mod2
print(sum)
# Out:
# 8

# %%
getNumber=input()
numbers=getNumber.split()

n1=int(numbers[0])
n2=int(numbers[1])

mod1=n1%10
mod2=n2%10

sum=mod1+mod2

print("Summation of last digit:",sum)
# Out:
# Summation of last digit: 5
