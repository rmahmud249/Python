# %%
x=20; y=3
sum=x+y
sub=x-y
mult=x*y
div=round(x/y , 2)
mod=x%y
print(sum, sub, mult, div, mod)
# Out:
# 23 17 60 6.67 2

# %%
x= 10; y= 3

greater_than= x > y 
print(greater_than)
# Out:
# True

# %%
#precedence and associativity 
#(/, *)=> Higher precedence (Count: Left -> Right)
#(+, -)=> Lower precedence  (Count: left -> Right)

pa=10+10/2-5*2
print(pa) #10+5-10
          #15-10
          # 5
# Out:
# 5.0
