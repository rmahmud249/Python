# %%
age=23

if age >= 18:
    print("You are adult")
# Out:
# You are adult

# %%
age=16

if age >= 18:
    print("You are adult")
else:
    print("Your are not adult")
# Out:
# Your are not adult

# %%
marks=75

if marks >= 80:
    print("Grades A+")
elif marks >= 70:
    print("Grades A")
elif marks >=60:
    print("Grades A-")
else:
    print("Fail")
# Out:
# Grades A

# %%
username="admin"
password=1234

if username=="admin" and password==1234:
    print("Login successful")
else:
    print("Login failed")
# Out:
# Login successful

# %%
num1=int(input("Enter a number: "))

if num1 % 2 == 0:
    print("Number Is Even")
else:
    print("Number Is Odd")
# Out:
# Number Is Even

# %%
a=3;b=4;c=8
if (a>b) and (a>c):
    print("a, is larger")
elif (b>a) and (b>c):
    print("b is larger")
else:
    print("c is larger")
# Out:
# c is larger

# %%
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))

even=0
odd=0

for i in range(num1,num2+1):
    if i % 2 == 0:
        even=even+i
    else:
        odd=odd+i

print("Summation of even number:",even)
print("Summation of odd number:",odd)
# Out:
# Summation of even number: 6
# Summation of odd number: 4

# %%
n=int(input("Enter a number: "))
fact=1
for i in range(1,n+1):
    fact=fact*i
print("Factorial of N :",fact)
# Out:
# Factorial of N : 120

# %%
n=int(input("Enter a number: "))
is_prime=0

for i in range(2,n):
    if n % i == 0:
        is_prime=1
        print("This number is not prime")
        break

if is_prime == 0:
    print("This number is prime")
# Out:
# This number is not prime
