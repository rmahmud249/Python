# %%
number=1230
print(number)
# Out:
# 1230

# %%
name="Rasel Mahmud"
print(name)
# Out:
# Rasel Mahmud

# %%
name= "Farhan ishraque"
age=23
height=5.6
is_passed=True

print("Age type:", type(age))
print("Name type:", type(name))
print("Height type:",type(height))
print("Is passed type:",type(is_passed))
# Out:
# Age type: <class 'int'>
# Name type: <class 'str'>
# Height type: <class 'float'>
# Is passed type: <class 'bool'>

# %%
#Taking Input
name=input("Enter your name: ")
print(name)
# Out:
# 23 <class 'str'>

# %%
age=input("Enter your age: ") #get age as a String
age=int(age)# convert string to integer
print(age, type(age))
# Out:
# 15 <class 'int'>

# %%
height=input("Enter height: ")
print(height,type(height))
# Out:
# 20.2 <class 'str'>

# %%
height=input("Enter height: ")
height=float(height)
print(height, type(height))
# Out:
# 20.3 <class 'float'>

# %%
height=float(input("Enter your height: "))#convert string to float 
print(height,type(height))
# Out:
# 20.2 <class 'float'>
